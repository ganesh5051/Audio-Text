# %%
# !pip install openai==0.28

# %%
import openai

# %%
#openai api key
OPENAI_API_KEY = "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"

# %%
#Load the openai key
openai.api_key = OPENAI_API_KEY

# %%
#audio file upload
audio_file = open("/content/sample-0.mp3", 'rb')

# %% [markdown]
# Even though MP3 is a supported format, the 'Invalid file format' error can happen if the file's internal pointer isn't at the beginning when the API tries to read it. I'll add audio_file.seek(0) before the translation call to ensure the file is read from the start.

# %%
#audio transilate
audio_file.seek(0)
output = openai.Audio.translate('whisper-1', audio_file)

# %%
print(output)
# Out:
# {
#   "text": "My thought, I have nobody by a beauty and will as you t'ward. Mr. Rochester is sub, and that so don't find simpus, And devoted abode, to hath might in a"
# }
